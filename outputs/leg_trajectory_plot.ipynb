# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
# Joint trajectories
t = np.linspace(0, 100, 100)
q1 = 45*np.sin(6*np.pi*t/100 - np.pi/2) + 75
q2 = -30*np.sin(6*np.pi*t/100 - np.pi/2) - 90
q = np.zeros((100, 2))
q[:,0] = q1
q[:,1] = q2
plt.plot(t,q1)
plt.plot(t,q2)

# %%
# End Effector trajectories

l1 = 0.5
l2 0.15 # arbirtratry
offset = ?

x1 = l1 * np.cos(np.pi*q1/180) + l2 * np.cos(np.pi*(q1 + q2)/180)
x2 = l1 * np.sin(np.pi*q1/180) + l2 * np.sin(np.pi*(q1 + q2)/180)
x3 = offset
x = np.zeros((100, 2))
x[:,0] = x1
x[:,1] = x2
plt.plot(t,x1)
plt.plot(t,x2)

# %%
file = open(r"ee_trajectories.txt","w+") 
for i in range(x.shape[0]):
    file.write(str(x[i, 0]) + "," + str(x[i,1]) + "\n")
file.close()

# %%
1) first going to the point
2) grab
3) follow trajectory
4) Ungrab 
5) final configuration
